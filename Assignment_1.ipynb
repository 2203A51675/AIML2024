# %% [markdown]
# Part-2 visualize the datasets or data using Matplot functions graphs

# %%
people =['ravi','suma','jeshu','sowmika','radha','devi',]
age = [40,36,16,15,35,45]
weight= [70,80,60,65,55,75]
height= [160,150,100,120,155,188]

import matplotlib.pyplot as plt

plt.scatter(weight, height)
plt.title("relation between weight and height of paients")
plt.ylabel("height in meters")
plt.xlabel("weight of patients in kgs")
plt.show

plt.figure(figsize =(12,4))
plt.title("people weight in kgs" , fontsize=16 , fontstyle='italic')

plt.bar(x=people,height=weight, width=0.6, color='orange', edgecolor='k', alpha=0.6)


plt.xlabel("people", fontsize=15)
plt.xticks(fontsize=14, rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("weight (in kgs)", fontsize=15)
plt.show()


import numpy as np
plt.figure(figsize=(7,5))

plt.hist(weight,color='red', edgecolor='k', alpha=0.75, bins=5)

plt.title("histogram", fontsize=18)
plt.xlabel("weights",fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# part-3 Access Data From  Various data sources using button function of Numpy and pandas

# %%
import pandas as pd
file1=pd.read_excel("/content/attendence.xlsx")
file1
# Out:
#    S.no   Name  H.no  attendence
# 0     1   ravi  1675        0.80
# 1     2   suma  1767        0.70
# 2     3  jeshu  1676        0.75
# 3     4  radha  1423        0.85
# 4     5   devi  1059        0.90

# %%
import pandas as pd
file2=pd.read_table("/content/attendence.xlsx.txt")
file2
# Out:
#    S.no   Name  H.no attendence
# 0     1   ravi  1675        80%
# 1     2   suma  1767        70%
# 2     3  jeshu  1676        75%
# 3     4  radha  1423        85%
# 4     5   devi  1059        90%

# %%
import pandas as pd
file3=pd.read_csv("/content/attendence.csv")
file3
# Out:
#    S.no   Name  H.no attendence
# 0     1   ravi  1675        80%
# 1     2   suma  1767        70%
# 2     3  jeshu  1676        75%
# 3     4  radha  1423        85%
# 4     5   devi  1059        90%
